# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns
import statsmodels.api as sm

# %%
#df = pd.read_csv('runner.csv', sep = "\t")
#df = pd.read_csv('imc.csv', sep = "\t")
df = pd.read_csv('visits.csv', sep = "\t")
df
# Out:
#            date  visits
# 0    2023-01-01      56
# 1    2023-01-02      52
# 2    2023-01-03      83
# 3    2023-01-04      84
# 4    2023-01-05      94
# ..          ...     ...
# 313  2023-11-10     155
# 314  2023-11-11     126
# 315  2023-11-12      67
# 316  2023-11-13     140
# 317  2023-11-14       1
#
# [318 rows x 2 columns]

# %%
df['date'] = pd.to_datetime(df['date'])
df['dow'] = df['date'].dt.dayofweek

# %%
df['mon'] = df.apply(lambda row: 1 if row['dow']==0 else 0, axis=1) # monday
df['tue'] = df.apply(lambda row: 1 if row['dow']==1 else 0, axis=1) # tuesday
df['wed'] = df.apply(lambda row: 1 if row['dow']==2 else 0, axis=1) # wednesday
df['thu'] = df.apply(lambda row: 1 if row['dow']==3 else 0, axis=1) # thursday
df['fri'] = df.apply(lambda row: 1 if row['dow']==4 else 0, axis=1) # friday
df['sat'] = df.apply(lambda row: 1 if row['dow']==5 else 0, axis=1) # saturday
df['sun'] = df.apply(lambda row: 1 if row['dow']==6 else 0, axis=1) # sunday

# %%
model = LinearRegression(n_jobs=None, fit_intercept=True, copy_X=True)

# %%
x = df[['mon', 'tue', 'wed', 'thu', 'fri', 'sat', 'sun']].to_numpy()
y = df['visits']

# %%
model.fit(x, y)
model.score(x, y)
# Out:
# 0.4955531865806504

# %%
x = sm.add_constant(x)
model = sm.OLS(y, x).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 visits   R-squared:                       0.501
# Model:                            OLS   Adj. R-squared:                  0.491
# Method:                 Least Squares   F-statistic:                     51.99
# Date:                Mon, 26 Feb 2024   Prob (F-statistic):           3.81e-44
# Time:                        13:46:47   Log-Likelihood:                -1465.4
# No. Observations:                 318   AIC:                             2945.
# Df Residuals:                     311   BIC:                             2971.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        111.1420      1.204     92.304      0.000     108.773     113.511
# ...

# %%
# Y = PLAQUETAS
# X1 = MEDICACAO A
# X2 = MEDICACAO B
# X3 = MEDICACADO C
#
# Y = BETA0 + BETA1 * X1 + BETA2 * X2 + BETA3 * X3
#
# 100 = BETA0
# 20 = BETA1
# 40 = BETA2
# -30 = BETA3

# Y = 100
#  + 20*0
#  + 40*0
#  - 30*1

# INCREMENTO DE PLAQUETAS PARA A MEDICAÇÃO A É DE 20
# INCREMENTO DE PLAQUETAS PARA A MEDICAÇÃO B É DE 40
# INCREMENTO DE PLAQUETAS PARA A MEDICAÇÃO C É DE -30
