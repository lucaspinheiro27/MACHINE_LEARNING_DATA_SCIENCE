# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
import statsmodels.api as sm

# %%
df = pd.read_csv("salarios.csv", sep = "\t", decimal = ',', encoding='latin1')

# %% [markdown]
# - Forma de uma Regressão Linear (equação de 1º grau)
# # Y = b0 + b1 * X

# %% [markdown]
# - Declarando o modelo;
# - n_jobs indica a quantidade de processos paralelos que vão calcular a regressão linear
# - fit_intercept = False, indica que não há constante na equação criada; uso é raro!

# %%
model = LinearRegression(n_jobs=None, fit_intercept=True)

# %% [markdown]
# - X: são as minhas variáveis explicativas; tem que
# - ser produzido como array bidimensional
# - para acomodar múltiplas variáveis por observação.

# %%
x = df['anos_exp'].to_numpy().reshape(-1,1)

# %% [markdown]
# - Y: é um array unidimensional, pois só há 1 variável
# - sendo prevista

# %%
y = df['salario'].to_numpy()

# %% [markdown]
# - faz a modelagem da regressão linear, calculando o
# - intecepto e o coeficiente angular

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# - score calcula o r-quadrado

# %%
print(model.score(x, y))
# Out:
# 0.9854136517127601

# %% [markdown]
# - R-quadrado varia de 0 até 1.
# - 1 é melhor possível
# - 0 é pior possível
